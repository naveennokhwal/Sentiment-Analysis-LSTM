# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("C:\Learning\Machine-Learning\Deep_Learning_WorkSpace\projects\sentiment-analysis-project\data\\raw\\training_data.csv", usecols=[0,5], names=["label", "text"])

# %%
data.sample(5)
# Out:
#         label                                               text
# 923278      4  Legs are Uber smooth i fn love you and miss yo...
# 850165      4      So excited about the Rushers EB on the 25th!
# 501225      0  And she and her coworkers from the clinic have...
# 958493      4  @Miss_Higgs I dont think The Broons would make...
# 882645      4  Vote for 'Little Louisa'  here : http://tinyur...

# %%
data.shape
# Out:
# (1048576, 2)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048576 entries, 0 to 1048575
# Data columns (total 2 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   label   1048576 non-null  int64
#  1   text    1048576 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 16.0+ MB

# %%
data.isnull().sum()
# Out:
# label    0
# text     0
# dtype: int64

# %% [markdown]
# ### Distribution of labels

# %%
label_counts = data['label'].value_counts()

# %%
# Plotting the distribution of labels
plt.figure(figsize=(4,3))
label_counts.plot(kind='bar', color=['blue', 'red', 'green'])
plt.title('Distribution of Sentiment Labels')
plt.xlabel('Sentiment Labels')
plt.ylabel('Count')
plt.xticks(rotation=0)

# Plotting the distribution of labels as a pie chart
plt.figure(figsize=(4,4))
plt.pie(label_counts, labels=label_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Sentiment Labels')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %% [markdown]
# ### Text Length Analysis

# %%
# calculating numbers of characters in each doucmemt
char_length = data['text'].apply(len)

# calculating numbers of words in each doucmemt
word_count = data['text'].apply(lambda x: len(x.split()))

# %%
import matplotlib.pyplot as plt

# Plotting histogram of text lengths (word count)
plt.figure(figsize=(4, 3))
plt.hist(word_count, bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Text Lengths (Word Count)')
plt.xlabel('Number of Words')
plt.ylabel('Frequency')
plt.show()
